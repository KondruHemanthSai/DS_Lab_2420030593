# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'Age':[25,30,np.nan,40,35],
    'Department':['HR','Finance','Finance',np.nan,'IT']
})
print("Original Data")
print(df)
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Department'].fillna(df['Department'].mode()[0], inplace=True)
print("\nAfter Mean & Mode Imputation")
print(df)
# Out:
# Original Data
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
#
# After Mean & Mode Imputation
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
# C:\Users\kondr\AppData\Local\Temp\ipykernel_15696\4127644747.py:9: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# C:\Users\kondr\AppData\Local\Temp\ipykernel_15696\4127644747.py:10: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Department'].fillna(df['Department'].mode()[0], inplace=True)

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'Age':[25,30,np.nan,40,35],
    'Department':['HR','Finance','Finance',np.nan,'IT']
})
df.ffill(inplace=True)
print(df)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  30.0    Finance
# 3  40.0    Finance
# 4  35.0         IT

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'Age':[25,30,np.nan,40,35],
    'Department':['HR','Finance','Finance',np.nan,'IT']
})
df.bfill(inplace=True)
print(df)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  40.0    Finance
# 3  40.0         IT
# 4  35.0         IT

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'Age':[25,30,np.nan,40,35],
    'Department':['HR','Finance','Finance',np.nan,'IT']
})
print("Drop Rows")
print(df.dropna())
print("\nDrop Columns")
print(df.dropna(axis=1))
# Out:
# Drop Rows
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 4  35.0         IT
#
# Drop Columns
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
import pandas as pd
df = pd.DataFrame({
    'ID':[1,2,2,3,4,4],
    'Name':['Alice','Bob','Bob','Charlie','David','David'],
    'Age':[25,30,30,35,40,40]
})
print("Original Data")
print(df)
print("\nExact Duplicates Removed")
print(df.drop_duplicates())
print("\nDuplicates Removed Based on ID")
print(df.drop_duplicates(subset=['ID']))
# Out:
# Original Data
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
#
# Exact Duplicates Removed
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
#
# Duplicates Removed Based on ID
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
import pandas as pd
df = pd.DataFrame({
    'Date':['2025-01-05','05/01/2025','Jan 5, 2025','2025.01.05']
})
df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')
print(df)
# Out:
#          Date
# 0  2025-01-05
# 1         NaN
# 2         NaN
# 3         NaN

# %%
import pandas as pd
df = pd.DataFrame({
    'Name':['Alice','BOB','charlie','DAVID']
})
df['Lower'] = df['Name'].str.lower()
df['Upper'] = df['Name'].str.upper()
print(df)
# Out:
#       Name    Lower    Upper
# 0    Alice    alice    ALICE
# 1      BOB      bob      BOB
# 2  charlie  charlie  CHARLIE
# 3    DAVID    david    DAVID
